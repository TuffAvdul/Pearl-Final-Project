# %%
import pandas as pd
import numpy as np

# %%
import json

# %%
js_data = pd.read_json("yelp_academic_dataset_business.json" , lines=True)

# %%
data = pd.DataFrame(js_data)

# %%
data.head()
# Out:
#               business_id                                       full_address  \
# 0  vcNAWiLM4dR7D2nwwJ7nCA  4840 E Indian School Rd\nSte 101\nPhoenix, AZ ...
# 1  JwUE5GmEO-sH1FuwJgKBlQ            6162 US Highway 51\nDe Forest, WI 53532
# 2  uGykseHzyS5xAMWoN6YUqA                505 W North St\nDe Forest, WI 53532
# 3  LRKJF43s9-3jG9Lgx4zODg              4910 County Rd V\nDe Forest, WI 53532
# 4  RgDg-k9S5YD_BaxMckifkg                 631 S Main St\nDe Forest, WI 53532
#
#                                                hours  open  \
# 0  {'Tuesday': {'close': '17:00', 'open': '08:00'...  True
# 1                                                 {}  True
# 2  {'Monday': {'close': '22:00', 'open': '06:00'}...  True
# 3  {'Monday': {'close': '22:00', 'open': '10:30'}...  True
# 4  {'Monday': {'close': '22:00', 'open': '11:00'}...  True
#
#                                           categories       city  review_count  \
# ...

# %%
data.columns
# Out:
# Index(['business_id', 'full_address', 'hours', 'open', 'categories', 'city',
#        'review_count', 'name', 'neighborhoods', 'longitude', 'state', 'stars',
#        'latitude', 'attributes', 'type'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42153 entries, 0 to 42152
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   business_id    42153 non-null  object
#  1   full_address   42153 non-null  object
#  2   hours          42153 non-null  object
#  3   open           42153 non-null  bool
#  4   categories     42153 non-null  object
#  5   city           42153 non-null  object
#  6   review_count   42153 non-null  int64
#  7   name           42153 non-null  object
#  8   neighborhoods  42153 non-null  object
#  9   longitude      42153 non-null  float64
#  10  state          42153 non-null  object
#  11  stars          42153 non-null  float64
#  12  latitude       42153 non-null  float64
#  13  attributes     42153 non-null  object
#  14  type           42153 non-null  object
# dtypes: bool(1), float64(3), int64(1), object(10)
# memory usage: 4.5+ MB

# %%
data.shape
# Out:
# (42153, 15)

# %%
type(data.loc[0,"categories"])
# Out:
# list

# %%
data.loc[:,"categories"]
# Out:
# 0                              [Doctors, Health & Medical]
# 1                                            [Restaurants]
# 2                    [American (Traditional), Restaurants]
# 3        [Food, Ice Cream & Frozen Yogurt, Fast Food, R...
# 4                                   [Chinese, Restaurants]
#                                ...
# 42148        [Food, Desserts, Italian, Pizza, Restaurants]
# 42149    [Active Life, Barre Classes, Pilates, Fitness ...
# 42150                          [Yelp Events, Local Flavor]
# 42151                [Kosher, Italian, Pizza, Restaurants]
# 42152         [Food, Ethnic Food, Grocery, Specialty Food]
# Name: categories, Length: 42153, dtype: object

# %%
data_test = data.loc[:,["business_id" , "categories"]]
data_test.head()
# Out:
#               business_id                                         categories
# 0  vcNAWiLM4dR7D2nwwJ7nCA                        [Doctors, Health & Medical]
# 1  JwUE5GmEO-sH1FuwJgKBlQ                                      [Restaurants]
# 2  uGykseHzyS5xAMWoN6YUqA              [American (Traditional), Restaurants]
# 3  LRKJF43s9-3jG9Lgx4zODg  [Food, Ice Cream & Frozen Yogurt, Fast Food, R...
# 4  RgDg-k9S5YD_BaxMckifkg                             [Chinese, Restaurants]

# %%
data_test["categories"] = data_test["categories"].astype("str")

# %%
categories_values = data_test["categories"].unique()

# %%
count = 0
for i in categories_values:
    count+=1

# %%
count
# Out:
# 5945

# %%
data.columns
# Out:
# Index(['business_id', 'full_address', 'hours', 'open', 'categories', 'city',
#        'review_count', 'name', 'neighborhoods', 'longitude', 'state', 'stars',
#        'latitude', 'attributes', 'type'],
#       dtype='object')

# %%
data["type"].unique()
# Out:
# array(['business'], dtype=object)

# %%
data2 = pd.read_json("yelp_academic_dataset_review.json" , lines = True)

# %%
data_2 = pd.DataFrame(data2)
data_2.head()
# Out:
#                                   votes                 user_id  \
# 0  {'funny': 0, 'useful': 2, 'cool': 1}  Xqd0DzHaiyRqVH3WRG7hzg
# 1  {'funny': 0, 'useful': 2, 'cool': 0}  H1kH6QZV7Le4zqTRNxoZow
# 2  {'funny': 0, 'useful': 1, 'cool': 1}  zvJCcrpm2yOZrxKffwGQLA
# 3  {'funny': 0, 'useful': 0, 'cool': 0}  KBLW4wJA_fwoWmMhiHRVOA
# 4  {'funny': 0, 'useful': 2, 'cool': 1}  zvJCcrpm2yOZrxKffwGQLA
#
#                 review_id  stars       date  \
# 0  15SdjuK7DmYqUAj6rjGowg      5 2007-05-17
# 1  RF6UnRTtG7tWMcrO2GEoAg      2 2010-03-22
# 2  -TsVN230RCkLYKBeLsuz7A      4 2012-02-14
# 3  dNocEAyUucjT371NNND41Q      4 2012-03-02
# 4  ebcN2aqmNUuYNoyvQErgnA      4 2012-05-15
#
#                                                 text    type  \
# 0  dr. goldberg offers everything i look for in a...  review
# 1  Unfortunately, the frustration of being Dr. Go...  review
# 2  Dr. Goldberg has been my doctor for years and ...  review
# 3  Been going to Dr. Goldberg for over 10 years. ...  review
# ...

# %%
data_reveiw = pd.read_json("yelp_academic_dataset_review.json" , lines = True)

# %%
data_reveiw.shape
# Out:
# (1125458, 8)

# %%
data_reveiw.head()
# Out:
#                                   votes                 user_id  \
# 0  {'funny': 0, 'useful': 2, 'cool': 1}  Xqd0DzHaiyRqVH3WRG7hzg
# 1  {'funny': 0, 'useful': 2, 'cool': 0}  H1kH6QZV7Le4zqTRNxoZow
# 2  {'funny': 0, 'useful': 1, 'cool': 1}  zvJCcrpm2yOZrxKffwGQLA
# 3  {'funny': 0, 'useful': 0, 'cool': 0}  KBLW4wJA_fwoWmMhiHRVOA
# 4  {'funny': 0, 'useful': 2, 'cool': 1}  zvJCcrpm2yOZrxKffwGQLA
#
#                 review_id  stars       date  \
# 0  15SdjuK7DmYqUAj6rjGowg      5 2007-05-17
# 1  RF6UnRTtG7tWMcrO2GEoAg      2 2010-03-22
# 2  -TsVN230RCkLYKBeLsuz7A      4 2012-02-14
# 3  dNocEAyUucjT371NNND41Q      4 2012-03-02
# 4  ebcN2aqmNUuYNoyvQErgnA      4 2012-05-15
#
#                                                 text    type  \
# 0  dr. goldberg offers everything i look for in a...  review
# 1  Unfortunately, the frustration of being Dr. Go...  review
# 2  Dr. Goldberg has been my doctor for years and ...  review
# 3  Been going to Dr. Goldberg for over 10 years. ...  review
# ...

# %%
data_checkin = pd.read_json("yelp_academic_dataset_checkin.json" , lines= True)

# %%
data_checkin
# Out:
#                                             checkin_info     type  \
# 0      {'3-4': 1, '13-5': 1, '6-6': 1, '14-5': 1, '14...  checkin
# 1      {'9-3': 1, '12-5': 1, '15-3': 1, '15-5': 1, '7...  checkin
# 2      {'16-3': 1, '15-3': 2, '15-5': 1, '15-4': 1, '...  checkin
# 3                      {'11-4': 1, '10-6': 1, '15-6': 1}  checkin
# 4                       {'14-5': 1, '10-5': 1, '7-5': 1}  checkin
# ...                                                  ...      ...
# 31612  {'15-0': 2, '15-5': 4, '23-0': 1, '15-6': 1, '...  checkin
# 31613  {'20-2': 2, '14-1': 2, '15-1': 1, '19-4': 1, '...  checkin
# 31614  {'20-0': 1, '20-3': 1, '17-3': 1, '18-5': 1, '...  checkin
# 31615  {'0-2': 1, '20-1': 1, '19-1': 2, '19-2': 1, '1...  checkin
# 31616  {'15-1': 1, '20-3': 1, '19-6': 1, '22-5': 1, '...  checkin
#
#                   business_id
# 0      JwUE5GmEO-sH1FuwJgKBlQ
# 1      uGykseHzyS5xAMWoN6YUqA
# 2      LRKJF43s9-3jG9Lgx4zODg
# 3      RgDg-k9S5YD_BaxMckifkg
# ...

# %%
whos
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# categories_values   ndarray      5945: 5945 elems, type `object`, 47560 bytes
# count               int          5945
# data                DataFrame                      busines<...>[42153 rows x 15 columns]
# data2               DataFrame                             <...>1125458 rows x 8 columns]
# data_2              DataFrame                             <...>1125458 rows x 8 columns]
# data_checkin        DataFrame                             <...>n[31617 rows x 3 columns]
# data_reveiw         DataFrame                             <...>1125458 rows x 8 columns]
# data_test           DataFrame                      busines<...>n[42153 rows x 2 columns]
# i                   str          ['Bars', 'Turkish', 'Medi<...>'Lounges', 'Restaurants']
# js_data             DataFrame                      busines<...>[42153 rows x 15 columns]
# ...

# %%
data.columns
# Out:
# Index(['business_id', 'full_address', 'hours', 'open', 'categories', 'city',
#        'review_count', 'name', 'neighborhoods', 'longitude', 'state', 'stars',
#        'latitude', 'attributes', 'type'],
#       dtype='object')

# %%
data.loc[:,"categories"].astype(str).nunique()
# Out:
# 5945

# %%
sorted(data.loc[:,"categories"].astype(str).unique())
# Out:
# ['["Children\'s Clothing", "Men\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", "Men\'s Clothing", \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\', "Men\'s Clothing"]',
#  '["Children\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\', \'Accessories\']',
#  '["Children\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", \'Baby Gear & Furniture\', \'Fashion\', \'Shopping\', \'Toy Stores\']',
#  '["Children\'s Clothing", \'Department Stores\', \'Fashion\', \'Shopping\', "Men\'s Clothing", "Women\'s Clothing"]',
#  '["Children\'s Clothing", \'Department Stores\', \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", \'Department Stores\', \'Thrift Stores\', \'Shopping\', \'Fashion\']',
#  '["Children\'s Clothing", \'Fashion\', \'Shopping\', \'Accessories\', \'Shoe Stores\']',
# ...

# %%
whos
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# categories_values   ndarray      5945: 5945 elems, type `object`, 47560 bytes
# count               int          5945
# data                DataFrame                      busines<...>[42153 rows x 15 columns]
# data2               DataFrame                             <...>1125458 rows x 8 columns]
# data_2              DataFrame                             <...>1125458 rows x 8 columns]
# data_checkin        DataFrame                             <...>n[31617 rows x 3 columns]
# data_reveiw         DataFrame                             <...>1125458 rows x 8 columns]
# data_test           DataFrame                      busines<...>n[42153 rows x 2 columns]
# i                   str          ['Bars', 'Turkish', 'Medi<...>'Lounges', 'Restaurants']
# js_data             DataFrame                      busines<...>[42153 rows x 15 columns]
# ...

# %%
# (data.loc[:,"categories"].astype(str).nunique())

# %%
data["categories"].astype(str).nunique()
# Out:
# 5945

# %%
sorted(data["categories"].astype(str).unique())
# Out:
# ['["Children\'s Clothing", "Men\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", "Men\'s Clothing", \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\', "Men\'s Clothing"]',
#  '["Children\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\', \'Accessories\']',
#  '["Children\'s Clothing", "Women\'s Clothing", \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", \'Baby Gear & Furniture\', \'Fashion\', \'Shopping\', \'Toy Stores\']',
#  '["Children\'s Clothing", \'Department Stores\', \'Fashion\', \'Shopping\', "Men\'s Clothing", "Women\'s Clothing"]',
#  '["Children\'s Clothing", \'Department Stores\', \'Fashion\', \'Shopping\']',
#  '["Children\'s Clothing", \'Department Stores\', \'Thrift Stores\', \'Shopping\', \'Fashion\']',
#  '["Children\'s Clothing", \'Fashion\', \'Shopping\', \'Accessories\', \'Shoe Stores\']',
# ...
